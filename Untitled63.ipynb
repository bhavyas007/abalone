# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.nunique()
# Out:
# Sex                  3
# Length             134
# Diameter           111
# Height              51
# Whole weight      2429
# Shucked weight    1515
# Viscera weight     880
# Shell weight       926
# Rings               28
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# EDA

# %%
sns.countplot(df['Rings'])
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %% [markdown]
# Albone having 9 no of rings are heighest in quantity

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
df['Sex']=label.fit_transform(df['Sex'])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
sns.histplot(df['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %% [markdown]
# Male albone are heighest in quantity

# %%
sns.histplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Count'>

# %% [markdown]
# abalone of length 0.6-0.7 are heighest in quantity.

# %%
sns.histplot(df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Count'>

# %% [markdown]
# Maximum abalone are having diameter in 0.4-0.5 range.

# %%
sns.violinplot(df['Height'])
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %% [markdown]
# maximum height of abalone is 0.2

# %%
sns.histplot(df['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Count'>

# %% [markdown]
# maximum abalone are having weight in range 0.5-1.0

# %%
sns.histplot(df['Shucked weight'])
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Count'>

# %% [markdown]
# most of the abalone have sucked weight in range 0.2-0.4

# %%
sns.histplot(df['Viscera weight'])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Count'>

# %% [markdown]
# most of the abalone have sucked weight in range 0.2-0.4

# %%
sns.histplot(df['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Count'>

# %% [markdown]
# most of the abalone have shell weight in range 0.2-0.4

# %%
sns.countplot(df['Rings'])
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %% [markdown]
# most of abalone have 9 rings

# %%
sns.pairplot(df,hue='Sex')

# %% [markdown]
# Observations:
#     Length of male ablone is higher in compairson to Female
#     Male and Female ablone have same no of rings.
#     Diameter of male ablone is higher than Female abalone.
#     shucked weighted and viscera weight of female abalone is grater than male.
#     shell weight of female abalone is higher than male.

# %%
sns.pairplot(df)

# %% [markdown]
# # checking multicollinearity

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['features']= df.columns
    vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
    
    return(vif)

# %%
x=df.iloc[:,:-1]
calc_vif(x)
# Out:
#          features         VIF
# 0             Sex    2.563825
# 1          Length  702.347884
# 2        Diameter  755.416018
# 3          Height   43.004758
# 4    Whole weight  436.141083
# 5  Shucked weight  117.686245
# 6  Viscera weight   64.740171
# 7    Shell weight   82.562895
# 8           Rings   21.652131

# %% [markdown]
# Diameter and length have high multicollinearity factor.

# %%
x1=df.drop(['Diameter'],axis=1)

# %%
calc_vif(x1)
# Out:
#          features         VIF
# 0             Sex    2.563825
# 1          Length  702.347884
# 2        Diameter  755.416018
# 3          Height   43.004758
# 4    Whole weight  436.141083
# 5  Shucked weight  117.686245
# 6  Viscera weight   64.740171
# 7    Shell weight   82.562895
# 8           Rings   21.652131

# %%
df1=df.drop(['Diameter'],axis=1)

# %%
df1
# Out:
#       Sex  Length  Height  Whole weight  Shucked weight  Viscera weight  \
# 0       2   0.455   0.095        0.5140          0.2245          0.1010
# 1       2   0.350   0.090        0.2255          0.0995          0.0485
# 2       0   0.530   0.135        0.6770          0.2565          0.1415
# 3       2   0.440   0.125        0.5160          0.2155          0.1140
# 4       1   0.330   0.080        0.2050          0.0895          0.0395
# ...   ...     ...     ...           ...             ...             ...
# 4172    0   0.565   0.165        0.8870          0.3700          0.2390
# 4173    2   0.590   0.135        0.9660          0.4390          0.2145
# 4174    2   0.600   0.205        1.1760          0.5255          0.2875
# 4175    0   0.625   0.150        1.0945          0.5310          0.2610
# 4176    2   0.710   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# 0           0.1500     15
# 1           0.0700      7
# ...

# %% [markdown]
# checking skewness

# %%
df1.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# as we can say except height there is no skewness in data

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
df2=pt.fit_transform(df1)

# %%
df2
# Out:
# array([[ 1.12707158, -0.68550213, -1.12451192, ..., -0.69328289,
#         -0.587809  ,  1.48235844],
#        [ 1.12707158, -1.39634403, -1.26439579, ..., -1.33295268,
#         -1.33241968, -0.94913462],
#        [-1.30793479, -0.07077438, -0.06482301, ..., -0.25513514,
#         -0.09826193, -0.17607507],
#        ...,
#        [ 1.12707158,  0.59336612,  1.56508168, ...,  1.01560749,
#          0.59839786, -0.17607507],
#        [-1.30793479,  0.85337516,  0.30708344, ...,  0.81518436,
#          0.51914542,  0.15690844],
#        [ 1.12707158,  1.83447784,  1.34794324, ...,  1.61134422,
#          1.65848824,  0.74460653]])

# %%
df3=pd.DataFrame(df2)

# %%
df3
# Out:
#            Sex    Length    Height  Whole weight  Shucked weight  \
# 0     1.127072 -0.685502 -1.124512     -0.576766       -0.540989
# 1     1.127072 -1.396344 -1.264396     -1.351761       -1.311662
# 2    -1.307935 -0.070774 -0.064823     -0.198099       -0.366116
# 3     1.127072 -0.797286 -0.320227     -0.571893       -0.591672
# 4    -0.009459 -1.513796 -1.549424     -1.413146       -1.380201
# ...        ...       ...       ...           ...             ...
# 4172 -1.307935  0.249836  0.666117      0.241948        0.194158
# 4173  1.127072  0.492813 -0.064823      0.395706        0.495450
# 4174  1.127072  0.593366  1.565082      0.777944        0.838137
# 4175 -1.307935  0.853375  0.307083      0.633874        0.858739
# 4176  1.127072  1.834478  1.347943      1.937323        2.103648
#
#       Viscera weight  Shell weight     Rings
# 0          -0.693283     -0.587809  1.482358
# 1          -1.332953     -1.332420 -0.949135
# 2          -0.255135     -0.098262 -0.176075
# ...

# %%
df3.columns=df1.columns

# %%
df3.skew()
# Out:
# Sex              -0.176442
# Length           -0.066669
# Height           -0.115483
# Whole weight     -0.003980
# Shucked weight    0.027351
# Viscera weight    0.039780
# Shell weight      0.023390
# Rings             0.004429
# dtype: float64

# %% [markdown]
# checking for outliers

# %%
import scipy.stats as stats

# %%
from scipy.stats import zscore

# %%
stats.zscore(df3)
# Out:
#            Sex    Length    Height  Whole weight  Shucked weight  \
# 0     1.127072 -0.685502 -1.124512     -0.576766       -0.540989
# 1     1.127072 -1.396344 -1.264396     -1.351761       -1.311662
# 2    -1.307935 -0.070774 -0.064823     -0.198099       -0.366116
# 3     1.127072 -0.797286 -0.320227     -0.571893       -0.591672
# 4    -0.009459 -1.513796 -1.549424     -1.413146       -1.380201
# ...        ...       ...       ...           ...             ...
# 4172 -1.307935  0.249836  0.666117      0.241948        0.194158
# 4173  1.127072  0.492813 -0.064823      0.395706        0.495450
# 4174  1.127072  0.593366  1.565082      0.777944        0.838137
# 4175 -1.307935  0.853375  0.307083      0.633874        0.858739
# 4176  1.127072  1.834478  1.347943      1.937323        2.103648
#
#       Viscera weight  Shell weight     Rings
# 0          -0.693283     -0.587809  1.482358
# 1          -1.332953     -1.332420 -0.949135
# 2          -0.255135     -0.098262 -0.176075
# ...

# %%
z=np.abs(zscore(df3))
z.shape
# Out:
# (4177, 8)

# %%
np.where(z>3)
# Out:
# (array([ 163,  166,  236,  236,  237,  237,  238,  238,  294,  306,  306,
#          480,  520,  526,  694,  719,  719,  720,  720,  891,  894, 1054,
#         1174, 1209, 1257, 1417, 1428, 1429, 1763, 1987, 2051, 2108, 2108,
#         2115, 2161, 2169, 2171, 2172, 2201, 2209, 2334, 2371, 2381, 2711,
#         2711, 3149, 3190, 3280, 3472, 3521, 3801, 3902, 3996], dtype=int64),
#  array([6, 6, 2, 7, 2, 7, 2, 7, 7, 2, 7, 7, 7, 7, 2, 2, 7, 2, 7, 6, 7, 7,
#         2, 4, 2, 2, 1, 7, 5, 2, 2, 6, 7, 7, 6, 2, 2, 2, 7, 7, 1, 7, 2, 2,
#         7, 7, 2, 7, 7, 7, 7, 2, 2], dtype=int64))

# %%
df_new=df3[(z<3).all(axis=1)]
df_new
# Out:
#            Sex    Length    Height  Whole weight  Shucked weight  \
# 0     1.127072 -0.685502 -1.124512     -0.576766       -0.540989
# 1     1.127072 -1.396344 -1.264396     -1.351761       -1.311662
# 2    -1.307935 -0.070774 -0.064823     -0.198099       -0.366116
# 3     1.127072 -0.797286 -0.320227     -0.571893       -0.591672
# 4    -0.009459 -1.513796 -1.549424     -1.413146       -1.380201
# ...        ...       ...       ...           ...             ...
# 4172 -1.307935  0.249836  0.666117      0.241948        0.194158
# 4173  1.127072  0.492813 -0.064823      0.395706        0.495450
# 4174  1.127072  0.593366  1.565082      0.777944        0.838137
# 4175 -1.307935  0.853375  0.307083      0.633874        0.858739
# 4176  1.127072  1.834478  1.347943      1.937323        2.103648
#
#       Viscera weight  Shell weight     Rings
# 0          -0.693283     -0.587809  1.482358
# 1          -1.332953     -1.332420 -0.949135
# 2          -0.255135     -0.098262 -0.176075
# ...

# %%
colist=df3.columns.values
ncol=30
nrow=15

# %%
colist
# Out:
# array(['Sex', 'Length', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(colist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data=df[colist[i]],orient='v')
    plt.tight_layout()

# %% [markdown]
# as we can see outliers are present in our data

# %%
print("new_data",df_new.shape)
# Out:
# new_data (4132, 8)

# %%
print("old_data",df.shape)
# Out:
# old_data (4177, 9)

# %%
dataloss=(4177*9-4132*8)/4177*9
dataloss
# Out:
# 9.775676322719656

# %% [markdown]
# normalising the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x=df_new.iloc[:,:-1]

# %%
x
# Out:
#            Sex    Length    Height  Whole weight  Shucked weight  \
# 0     1.127072 -0.685502 -1.124512     -0.576766       -0.540989
# 1     1.127072 -1.396344 -1.264396     -1.351761       -1.311662
# 2    -1.307935 -0.070774 -0.064823     -0.198099       -0.366116
# 3     1.127072 -0.797286 -0.320227     -0.571893       -0.591672
# 4    -0.009459 -1.513796 -1.549424     -1.413146       -1.380201
# ...        ...       ...       ...           ...             ...
# 4172 -1.307935  0.249836  0.666117      0.241948        0.194158
# 4173  1.127072  0.492813 -0.064823      0.395706        0.495450
# 4174  1.127072  0.593366  1.565082      0.777944        0.838137
# 4175 -1.307935  0.853375  0.307083      0.633874        0.858739
# 4176  1.127072  1.834478  1.347943      1.937323        2.103648
#
#       Viscera weight  Shell weight
# 0          -0.693283     -0.587809
# 1          -1.332953     -1.332420
# 2          -0.255135     -0.098262
# 3          -0.547782     -0.544931
# ...

# %%
scaler.fit_transform(x)
# Out:
# array([[ 1.12434907, -0.70587143, -1.20000395, ..., -0.55442498,
#         -0.70816163, -0.60215614],
#        [ 1.12434907, -1.43037878, -1.3479014 , ..., -1.33544712,
#         -1.3563272 , -1.36099952],
#        [-1.30719912, -0.07932598, -0.07960818, ..., -0.37720364,
#         -0.26419461, -0.10325174],
#        ...,
#        [ 1.12434907,  0.59758217,  1.64366955, ...,  0.8432214 ,
#          1.0234254 ,  0.6067242 ],
#        [-1.30719912,  0.8625897 ,  0.31360383, ...,  0.86410006,
#          0.82034035,  0.52595691],
#        [ 1.12434907,  1.8625534 ,  1.41409182, ...,  2.12572777,
#          1.62707441,  1.68707744]])

# %%
x.mean()
# Out:
# Sex               0.001123
# Length            0.007055
# Height            0.010472
# Whole weight      0.004729
# Shucked weight    0.006089
# Viscera weight    0.005597
# Shell weight      0.003053
# dtype: float64

# %% [markdown]
# as we can see mean is equal to 0

# %%
x.std()
# Out:
# Sex               1.001543
# Length            0.981257
# Height            0.945931
# Whole weight      0.984007
# Shucked weight    0.986868
# Viscera weight    0.987012
# Shell weight      0.981363
# dtype: float64

# %% [markdown]
# and std is equal to 1, our data is perfectly fit

# %%
y=df_new.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error

# %%
lr=LinearRegression()

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
        print(i)
# Out:
# 70
# 108
# 111
# 129
# 236
# 289
# 354
# 414
# 464
# 469
# 623
# 689
# 696
# 728
# 842
# 864
# 910
# 914
# 929
# 965

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=842,test_size=0.2)

# %%
x_train.shape
# Out:
# (3305, 7)

# %%
x_test.shape
# Out:
# (827, 7)

# %%
y_train.shape
# Out:
# (3305,)

# %%
y_test.shape
# Out:
# (827,)

# %%
pred_train=lr.predict(x_train)

# %%
pred_train.shape
# Out:
# (3305,)

# %%
pred_test=lr.predict(x_test)

# %%
pred_test.shape
# Out:
# (827,)

# %%
r2=r2_score(y_train,pred_train)

# %%
r2
# Out:
# 0.5711796216332123

# %%
print('mean squared error: %.2f'% mean_squared_error(y_test,pred_test))
# Out:
# mean squared error: 0.37

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(n_estimators=200,random_state=1)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=1)

# %%
x_train.shape
# Out:
# (3305, 7)

# %%
y_train.shape
# Out:
# (3305,)

# %%
x_test_pred=model.predict(x_test)

# %%
x_train_pred=model.predict(x_train)

# %%
r2_score(x_test_pred,y_test)
# Out:
# 0.4156709581819926

# %%
print('mean squared error: %.2f'% mean_squared_error(y_test,x_test_pred))
# Out:
# mean squared error: 0.34

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model1=KNeighborsRegressor(n_neighbors=3)

# %%
model1.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
x_test_pred=model1.predict(x_test)

# %%
x_train_pred=model1.predict(x_train)

# %%
r2_score(x_test_pred,y_test)
# Out:
# 0.3005322331070911

# %%
from sklearn.svm import SVR

# %%
model_2=SVR()

# %%
model_2.fit(x_train,y_train)
# Out:
# SVR()

# %%
x_test_pred=model_2.predict(x_test)

# %%
x_train_pred=model_2.predict(x_train)

# %%
r2_score(x_test_pred,y_test)
# Out:
# 0.3501592815901242

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_3=DecisionTreeRegressor(random_state=6)

# %%
model_3.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=6)

# %%
x_test_pred=model_3.predict(x_test)

# %%
x_train_pred=model_3.predict(x_train)

# %%
r2_score(x_test_pred,y_test)
# Out:
# 0.24693733627793724

# %%
from sklearn.model_selection import GridSearchCV

# %%
dict1={'Kernel':['rbf','poly','linear']}

# %%
model=SVR()

# %%
gd=GridSearchCV(estimator=model,param_grid=dict1 ,cv=5)

# %%
model.fit(x_train,y_train)
# Out:
# SVR()

# %%
x_train_pred=model.predict(x_train)

# %%
x_test_pred=model.predict(x_test)

# %%
r2_score(x_test_pred,y_test)
# Out:
# 0.3501592815901242

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn import linear_model
lasso= linear_model.Lasso()
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
 clf=SVR(kernel='linear')

# %%
scores=cross_val_score(clf,x,y,cv=5)

# %%
scores
# Out:
# array([0.39784608, 0.44662827, 0.53501003, 0.55216666, 0.55149496])

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.50 accuracy with a standard deviation of 0.06

# %%
import pickle

# %%
saved_model=pickle.dumps(model)

# %%
knn_from_pickle=pickle.loads(saved_model)

# %%
knn_from_pickle.predict(x_test)
# Out:
# array([ 0.19134702, -0.6737667 , -0.70886164,  0.35558479,  0.19667864,
#         0.00919379,  0.65725653,  0.25403901, -0.73361405,  0.52936886,
#        -1.10788422,  0.30093763, -0.70638853, -1.40644451,  1.40142549,
#         0.41373637, -0.07238399, -0.56811306,  0.06011414,  0.83942805,
#         0.06235612,  0.27584175,  0.19324555,  0.56432709, -1.15356883,
#         0.60093237, -1.19047885,  0.28842304, -1.28830908,  0.16890591,
#        -0.17490306, -1.05461865,  0.46140033, -0.15726254, -2.17743967,
#         0.57125525,  0.13794094, -0.29580972, -0.41046738,  0.13885778,
#        -0.06897815, -0.13689946,  0.96922647, -0.33044676, -0.36978465,
#         0.22236651,  0.74823694, -0.21113825,  0.0693562 ,  0.01390955,
#         0.51829045, -0.28015252,  0.37499603, -0.09956779,  0.32044884,
#        -0.01722524, -0.60463624,  0.23274451,  0.34367455, -0.18673428,
#         0.62132063,  0.33353331,  0.2840918 ,  0.43190758,  1.13877187,
# ...

# %%
x_test.shape
